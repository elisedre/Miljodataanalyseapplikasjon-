# %% [markdown]
# Generert data

# %%
import os
from dotenv import load_dotenv

load_dotenv()

client_id = os.getenv('client_id')
endpoint = 'https://frost.met.no/sources/v0.jsonld'
parameters = {
    'types': 'SensorSystem',  
    'country': 'NO',      
}

# %%
import sys

sys.path.insert(0, '../src')
from get_stations import get_stations
get_stations(endpoint, parameters, client_id)
# Out:
# ID: SN47230, Navn: ÅKRA UNGDOMSSKOLE
# ID: SN20952, Navn: STATFJORD C
# ID: SN23670, Navn: E16 RYFOSS
# ID: SN59450, Navn: STADLANDET
# ID: SN55000, Navn: LUSTER - ORNES
# ID: SN12590, Navn: E6 MJØSBRUA
# ID: SN26640, Navn: E134 DARBU
# ID: SN67650, Navn: FV30 REITSTØA
# ID: SN18269, Navn: OSLO - HAUGENSTUA
# ID: SN68090, Navn: TRONDHEIM - GRANÅSEN
# ID: SN57790, Navn: MYKLEBUSTFJELLET
# ID: SN27860, Navn: KVELDE
# ID: SN61065, Navn: E136 TRESFJORDBRUA
# ID: SN18700, Navn: OSLO - BLINDERN
# ID: SN27600, Navn: SANDEFJORD
# ID: SN87110, Navn: ANDØYA
# ID: SN40250, Navn: VALLE
# ID: SN40905, Navn: RV9 BJÅEN
# ID: SN27295, Navn: FV307 GRAVDAL
# ID: SN43220, Navn: FV44 SÆLEBØ
# ID: SN19660, Navn: E16 SKUI
# ID: SN18260, Navn: OSLO - HØYBRÅTEN
# ID: SN49240, Navn: RV13 LÅTEFOSS
# ID: SN77295, Navn: SVENNINGDAL
# ID: SN52990, Navn: ORTNEVIK
# ID: SN5350, Navn: NORD-ODAL
# ID: SN76963, Navn: KRISTINFELTET
# ID: SN92170, Navn: OKSFJORD
# ID: SN90295, Navn: SESSØYA
# ID: SN80740, Navn: REIPÅ
# ID: SN27564, Navn: SANDEFJORD - MOSSERØD
# ID: SN1070, Navn: HVALER - BREKKE
# ID: SN71230, Navn: FV755 MELTINGEN
# ID: SN26990, Navn: SANDE - GALLEBERG
# ID: SN8840, Navn: BARKALD
# ID: SN810, Navn: TUFSINGDAL - MIDTDAL
# ID: SN55520, Navn: FV55 INDRE HAFSLO
# ID: SN76918, Navn: EKOFISK - METBØYE B
# ID: SN60670, Navn: FV650 LIABYGDA
# ID: SN63595, Navn: RV70 GRÅURA
# ID: SN90250, Navn: E6 HEIA
# ID: SN76954, Navn: GJØAFELTET
# ID: SN76927, Navn: OSEBERG A
# ID: SN34580, Navn: DRANGEDAL-REFSDALSKILEN
# ID: SN76245, Navn: FV17 VÅG
# ID: SN26864, Navn: DRAMMEN SYKEHUS
# ID: SN55260, Navn: FV55 HERVAVATN
# ID: SN76999, Navn: SCARABEO 8
# ID: SN76936, Navn: SNORRE B
# ID: SN44485, Navn: E39 SØYLAND
# ID: SN19830, Navn: FV289 HURUM
# ID: SN27214, Navn: VÅLE
# ID: SN26900, Navn: DRAMMEN - BERSKOG
# ID: SN19525, Navn: BÆRUMS VERK
# ID: SN79215, Navn: E6 YTTERVIKA
# ID: SN50505, Navn: KV5738 NATTLANDSFJELLET
# ID: SN61630, Navn: BJORLI
# ID: SN91551, Navn: BIRTAVARRE - HOLMEN
# ID: SN83710, Navn: DRAG - AJLUOKTA
# ID: SN31700, Navn: FV37 JØNJILJO
# ID: SN46432, Navn: RØLDALSFJELLET - ELVERSHEI
# ID: SN82310, Navn: BODØ - SKIVIKA
# ID: SN78910, Navn: FV17 HØYLANDET
# ID: SN50514, Navn: FV560 KROSSLEITET
# ID: SN8140, Navn: EVENSTAD
# ID: SN58750, Navn: NORDFJORDEID
# ID: SN76909, Navn: JOHAN CASTBERG
# ID: SN98648, Navn: RAGNAROKK
# ID: SN27160, Navn: HORTEN II
# ID: SN85450, Navn: SVOLVÆR LUFTHAVN
# ID: SN15730, Navn: BRÅTÅ - SLETTOM
# ID: SN85890, Navn: RØST LUFTHAVN
# ID: SN47060, Navn: E39 AKSDAL SØR
# ID: SN39030, Navn: KRISTIANSAND - HÅNES
# ID: SN23500, Navn: LØKEN I VOLBU
# ID: SN50810, Navn: ÅSANE
# ID: SN81790, Navn: E6 STØDI BRU
# ID: SN4040, Navn: ENEBAKK - BARBØL
# ID: SN44530, Navn: TJELTA
# ID: SN4390, Navn: KLØFTA
# ID: SN14420, Navn: RV15 EIDEFOSSEN
# ID: SN72710, Navn: OVERHALLA - SKOGMO
# ID: SN58705, Navn: RV15 STRYNEFJELL-KVITENOVA
# ID: SN98630, Navn: E75 KOMAGVÆR
# ID: SN47275, Navn: E134 KARMSUNDBRUA
# ID: SN42520, Navn: RISNES I FJOTLAND
# ID: SN50245, Navn: FV48 TYSSE VEST
# ID: SN59800, Navn: SVINØY FYR
# ID: SN52452, Navn: E39 NORDHORDLANDSBRUA
# ID: SN23410, Navn: FAGERNES LUFTHAMN
# ID: SN12680, Navn: LILLEHAMMER - SÆTHERENGEN
# ID: SN59665, Navn: VOLDA BRANNSTASJON
# ID: SN99500, Navn: SKOGFOSS
# ID: SN64510, Navn: TINGVOLL
# ID: SN17650, Navn: E6 VESTBY
# ID: SN42810, Navn: TONSTAD - NETTFED
# ID: SN30330, Navn: GJERPEN - ÅRHUS
# ID: SN93070, Navn: E6 STORVIKEIDET
# ID: SN51010, Navn: FOSSMARK
# ID: SN3370, Navn: ØSAKER
# ID: SN99090, Navn: E6 GANDVIKBAKKEN
# ID: SN44730, Navn: SANDNES - ROVIK
# ID: SN4590, Navn: E16 ROMERIKSÅSEN
# ID: SN71385, Navn: FV715 HOGSDALEN
# ID: SN51800, Navn: MJØLFJELL UH
# ID: SN31900, Navn: TUDDAL
# ID: SN57380, Navn: RV5 LUNDEBOTN
# ID: SN17895, Navn: E18 SVARTSKOG
# ID: SN90612, Navn: RINGVASSØYA - DAMVATNET
# ID: SN56420, Navn: FURENESET
# ID: SN80707, Navn: GLOMFJORD - TVERRFJELLET
# ID: SN59695, Navn: ØRSTA - EITREFJELL
# ID: SN91150, Navn: LYNGEN - URA
# ID: SN18317, Navn: OSLO - ELVEBAKKEN
# ID: SN70820, Navn: UTGÅRD
# ID: SN3280, Navn: RAKKESTAD - SANDER
# ID: SN16271, Navn: HØVRINGEN II
# ID: SN44640, Navn: STAVANGER - VÅLAND
# ID: SN26580, Navn: DRAMMEN - BANGELØKKA
# ID: SN86090, Navn: VESTVÅGØY - HAGVÅGEN
# ID: SN47260, Navn: HAUGESUND LUFTHAVN
# ID: SN61310, Navn: FV63 TROLLSTIGEN
# ID: SN53280, Navn: E16 FLÅM
# ID: SN71780, Navn: ÅFJORD II
# ID: SN65060, Navn: E39 VALSØYFJORDEN
# ID: SN29720, Navn: DAGALI LUFTHAVN
# ID: SN94640, Navn: E69 NORDKAPP
# ID: SN62270, Navn: MOLDE LUFTHAVN
# ID: SN37310, Navn: GRYTÅI
# ID: SN50517, Navn: SOTRA - STYKKHAUGEN
# ID: SN54590, Navn: E16 HONING BRU
# ID: SN87795, Navn: TJELDSUNDET
# ID: SN30285, Navn: SKIEN - BORGEÅSEN
# ID: SN27262, Navn: TØNSBERG - KARLSVIK
# ID: SN13750, Navn: ØVRE HEIMDALSVATN
# ID: SN19923, Navn: E18 LIERSKOGEN
# ID: SN54330, Navn: E16 BORGUND
# ID: SN52930, Navn: BREKKE I SOGN
# ID: SN46300, Navn: SULDALSVATN
# ID: SN87660, Navn: RV83 SELJESTAD
# ID: SN88010, Navn: E6 GRATANGSFJELLET
# ID: SN19815, Navn: FV281 HURUM − STORSAND
# ID: SN90630, Navn: FV863 GAMNES
# ID: SN76966, Navn: OSEBERG ØST
# ID: SN6160, Navn: ÅSNES
# ID: SN47170, Navn: NORHEIM
# ID: SN27271, Navn: TØNSBERG GJESTEHAVN
# ID: SN26840, Navn: KROKSTADELVA - LANGELØKKA
# ID: SN47610, Navn: BASURA
# ID: SN79720, Navn: LAPPSÆTRA
# ID: SN8780, Navn: LI BRU
# ID: SN12180, Navn: ILSENG
# ID: SN40890, Navn: BREIDVATN
# ID: SN68290, Navn: SELBU II
# ID: SN497459020, Navn: ULVEN-FÅBERG-20
# ID: SN90495, Navn: STAKKEVOLLAN
# ID: SN33300, Navn: HONNEGRASNUTEN
# ID: SN60242, Navn: ÅKNESSKARET
# ID: SN66630, Navn: FV700 VOLL
# ID: SN27800, Navn: HEDRUM
# ID: SN18245, Navn: OSLO - AMMERUD
# ID: SN77280, Navn: LAKSFORS
# ID: SN76939, Navn: VALHALL A
# ID: SN27540, Navn: SANDEFJORD - GJEKSTAD
# ID: SN56250, Navn: E39 ÅRBERGSDALEN
# ID: SN76957, Navn: TROLL B
# ID: SN19510, Navn: ØVREVOLL
# ID: SN26894, Navn: DRAMMEN - GULSKOGEN
# ID: SN55290, Navn: SOGNEFJELLHYTTA
# ID: SN60870, Navn: SULA - LANGEVÅG
# ID: SN50526, Navn: RV555 SOTRABRUA
# ID: SN19932, Navn: GLITREVANN
# ID: SN50508, Navn: STORE KONGSHAUGEN
# ID: SN39212, Navn: E39 FIDJANE
# ID: SN26230, Navn: FV287 SANDSBRÅTEN
# ID: SN27450, Navn: MELSOM
# ID: SN76930, Navn: NORNE
# ID: SN98265, Navn: FV890 GEDNJE
# ID: SN63580, Navn: ÅNGÅRDSVATNET
# ID: SN90980, Navn: OLDERVIK
# ID: SN58780, Navn: NORDFJORDEID - NYMARK
# ID: SN55550, Navn: HAFSLO
# ID: SN42720, Navn: BAKKE
# ID: SN97251, Navn: KARASJOK - MARKANNJARGA
# ID: SN83300, Navn: STEIGEN
# ID: SN85480, Navn: E10 GIMSØYSTRAUMEN BRU
# ID: SN97350, Navn: CUOVDDATMOHKKI
# ID: SN88100, Navn: BONES I BARDU
# ID: SN57150, Navn: E39 HALBRENDSLIA
# ID: SN34370, Navn: E18 GJERDEMYRA
# ID: SN90480, Navn: E8 BREIVIKA
# ID: SN34810, Navn: TØRDAL - KLEPPE
# ID: SN73550, Navn: GARTLAND
# ID: SN27435, Navn: NØTTERØY - VESTSKOGEN
# ID: SN88623, Navn: STEINFJORD
# ID: SN19405, Navn: BÆRUM - STORØYA
# ID: SN27130, Navn: FV310 KOTTERØD
# ID: SN67270, Navn: E6 SOKNEDAL
# ID: SN96850, Navn: TANA BRU
# ID: SN13125, Navn: E6 TINGBERG
# ID: SN57365, Navn: E39 SVIDALSNESET
# ID: SN96931, Navn: POLMAK TOLLSTED
# ID: SN54180, Navn: LJØSNE
# ID: SN8720, Navn: ATNSJØEN
# ID: SN46150, Navn: SAND I RYFYLKE II
# ID: SN68230, Navn: TRONDHEIM - RISVOLLAN
# ID: SN29400, Navn: SANDHAUG
# ID: SN30270, Navn: PORSGRUNN - KJØLNES
# ID: SN80880, Navn: SANDHORNØYA - VÅTVIKFJELLET
# ID: SN70850, Navn: SNÅSA - KJEVLIA
# ID: SN30279, Navn: SKIEN - TORSBERG
# ID: SN91530, Navn: GAMANJUNNI
# ID: SN42490, Navn: FV42 HADDELANDSHEIA
# ID: SN48070, Navn: E39 STORDABRUA
# ID: SN27085, Navn: HOLMESTRAND II
# ID: SN19710, Navn: ASKER
# ID: SN69190, Navn: FV705 SELBUSKOGEN
# ID: SN1650, Navn: STRØMSFOSS SLUSE
# ID: SN43010, Navn: EIK - HOVE
# ID: SN89233, Navn: FV86 ANDSVANNET
# ID: SN81930, Navn: STORSTILLA
# ID: SN91180, Navn: LENANGSSTRAUMEN
# ID: SN15951, Navn: RV15 BREIDALEN II
# ID: SN27040, Navn: SANDE - GUNNESTAD
# ID: SN48061, Navn: FV542 BREMNES
# ID: SN16265, Navn: E6 ROSTEN
# ID: SN1300, Navn: FV220 HOLENE BRU
# ID: SN9303, Navn: E6 HJERKINN
# ID: SN3480, Navn: E18 MELLEBY
# ID: SN91727, Navn: ARNØYHAMN
# ID: SN26780, Navn: SOLBERGELVA - OLLEVEIEN
# ID: SN77390, Navn: E6 SEFRIVATNET
# ID: SN77049, Navn: MS ASTERIX
# ID: SN59680, Navn: ØRSTA-VOLDA LUFTHAMN
# ID: SN4781, Navn: GARDERMOEN SØR
# ID: SN44580, Navn: STAVANGER - MADLA
# ID: SN45675, Navn: RV13 ÅRDAL
# ID: SN51991, Navn: MYRKDALEN - VETLEBOTN II
# ID: SN39520, Navn: RV9 MOISUND
# ID: SN78350, Navn: BARDAL
# ID: SN41090, Navn: MANDAL III
# ID: SN33240, Navn: RAULAND II
# ID: SN92750, Navn: HASVIK LUFTHAVN
# ID: SN60640, Navn: VALLDAL - MURI
# ID: SN99380, Navn: KIRKENES LUFTHAVN - HØYDE 212
# ID: SN87950, Navn: GRATANGEN - SKJÆRVIKA
# ID: SN44562, Navn: ULLANDHAUG
# ID: SN86290, Navn: GIMSØY - ÅRRSTRANDA
# ID: SN23550, Navn: BEITOSTØLEN II
# ID: SN26852, Navn: DRAMMEN - BRAGERNES SKOLE
# ID: SN46850, Navn: HUNDSEID I VIKEDAL
# ID: SN53480, Navn: KLEVAVATNET
# ID: SN30261, Navn: PORSGRUNN
# ID: SN30288, Navn: SKIEN - KJØRBEKKSVINGEN
# ID: SN66005, Navn: VALSET FERJEKAI
# ID: SN76780, Navn: SANDNESSJØEN - ÅSEN
# ID: SN88650, Navn: SENJA - BOTNHAMN
# ID: SN32540, Navn: RV36 ULEFOSS
# ID: SN52565, Navn: FONNES - DROGEFLUA
# ID: SN47272, Navn: DUEHAMMAR
# ID: SN25165, Navn: RV52 HEMSEDALSFJELLET
# ID: SN12210, Navn: ARSTADTAJET
# ID: SN59850, Navn: E39 BJØRNDALSBRUA
# ID: SN60945, Navn: ÅLESUND IV
# ID: SN32890, Navn: HØYDALSMO II
# ID: SN69100, Navn: VÆRNES
# ID: SN27480, Navn: SANDEFJORD - NORDRE BERGAN
# ID: SN24600, Navn: GRIMELI I KRØDSHERAD
# ID: SN60810, Navn: LEBERGSFJELLET
# ID: SN19459, Navn: ØSTERÅS
# ID: SN30243, Navn: KJØRTINGEN
# ID: SN37600, Navn: FV355 VEUM
# ID: SN53160, Navn: JORDALEN - NÅSEN
# ID: SN30282, Navn: SKIEN - RØDMYRLIA
# ID: SN29600, Navn: TUNHOVD
# ID: SN18170, Navn: OSLO - ØSTENSJØ
# ID: SN70960, Navn: E6 SNÅSA
# ID: SN67560, Navn: KOTSØY
# ID: SN29950, Navn: SVENNER FYR
# ID: SN59530, Navn: FV61 KVILEHYTTA
# ID: SN34095, Navn: FV363 STOKKEBAKKEN
# ID: SN61064, Navn: VESTNES - RÅDHUSET
# ID: SN86921, Navn: ANDA FYR II
# ID: SN30246, Navn: FV2962 PAULER
# ID: SN88626, Navn: SENJAHOPEN
# ID: SN46530, Navn: VIVASSDALEN
# ID: SN67210, Navn: E6 HORG
# ID: SN94242, Navn: HAMMERFEST HAVN
# ID: SN81915, Navn: SULITJELMA - FAGERLI
# ID: SN32220, Navn: LIFJELL - ØYSTEINNATTEN
# ID: SN18215, Navn: OSLO - BROBEKK
# ID: SN90510, Navn: TROMSDALEN
# ID: SN27770, Navn: STOKKE - SOLLI
# ID: SN75410, Navn: NORDØYAN FYR
# ID: SN48450, Navn: HUSNES
# ID: SN40420, Navn: BYKLE - KULTRAN
# ID: SN79600, Navn: MO I RANA LUFTHAVN
# ID: SN88500, Navn: GRYLLEFJORD
# ID: SN81780, Navn: E6 SEMSKA
# ID: SN82220, Navn: RV80 HUNSTAD
# ID: SN43390, Navn: RV426 SLEVELAND IOT
# ID: SN41990, Navn: E39 VATLAND
# ID: SN27330, Navn: TØNSBERG - TARANRØD
# ID: SN94870, Navn: OLDERFJORD
# ID: SN90770, Navn: HELGØYA - MJØNES
# ID: SN52505, Navn: MARØY
# ID: SN49087, Navn: FOLGEFONNA SKISENTER TOPP
# ID: SN76460, Navn: BREMSTEIN FYR
# ID: SN27420, Navn: TJØME
# ID: SN47445, Navn: E39 SVEIO
# ID: SN57000, Navn: FØRDE LH - BRINGELAND
# ID: SN68125, Navn: SVERRESBORG
# ID: SN86598, Navn: STOKMARKNES LH - VEST
# ID: SN98360, Navn: BÅTSFJORD - STRAUMSNESAKSLA
# ID: SN13110, Navn: E6 FÅBERG
# ID: SN11710, Navn: EINAVATN
# ID: SN77043, Navn: DEEPSEA NORDKAPP
# ID: SN28380, Navn: KONGSBERG BRANNSTASJON
# ID: SN47194, Navn: SKUDENES UNGDOMSSKOLE
# ID: SN30255, Navn: PORSGRUNN - ÅS
# ID: SN496228018, Navn: HAMANG-BÆRUM-18
# ID: SN99670, Navn: JARFJORDEN - SKARVFJELL
# ID: SN55430, Navn: JOSTEDALEN - MJØLVERSGRENDI
# ID: SN30650, Navn: NOTODDEN LUFTHAVN
# ID: SN38150, Navn: E18 INNTJORHEIA
# ID: SN17820, Navn: E6 NØSTVET
# ID: SN18233, Navn: OSLO - NYLAND
# ID: SN91380, Navn: SKIBOTN II
# ID: SN44520, Navn: HELLAND I GJESDAL
# ID: SN46090, Navn: RV13 EIANE
# ID: SN44610, Navn: KVITSØY - NORDBØ
# ID: SN55735, Navn: RV5 FRUDALEN
# ID: SN17775, Navn: FAGERSTRAND
# ID: SN64330, Navn: KRISTIANSUND LUFTHAVN
# ID: SN39200, Navn: KRISTIANSAND - KVADRATUREN
# ID: SN57700, Navn: RV5 GROV
# ID: SN71750, Navn: BREIVOLL
# ID: SN31520, Navn: GROSET
# ID: SN82130, Navn: RV80 NORDVIKA
# ID: SN91685, Navn: VORTERØYSKAGEN
# ID: SN24890, Navn: NESBYEN - TODOKK
# ID: SN63630, Navn: TROLLHEIMEN - STORHORNET
# ID: SN26765, Navn: SUNDBYFOSS
# ID: SN51940, Navn: E16 VINJE VEST
# ID: SN40510, Navn: BLÅSJØ
# ID: SN91120, Navn: LYNGEN - GJERDELVDALEN
# ID: SN59010, Navn: MÅLØY - KULEN
# ID: SN64590, Navn: FV65 ØVRE RINDAL
# ID: SN50570, Navn: SKREDDERDALEN
# ID: SN12960, Navn: SJUSJØEN - STORÅSEN
# ID: SN54320, Navn: BORGUND - LO
# ID: SN64970, Navn: FV65 SURNADAL - NORDMARKA
# ID: SN76965, Navn: OSEBERG C
# ID: SN31855, Navn: FV3420 AMBJØRNDALEN
# ID: SN17850, Navn: ÅS
# ID: SN57030, Navn: FV609 HOLMEDAL VEST
# ID: SN91060, Navn: SJURSNES
# ID: SN27261, Navn: TØNSBERG - VALLØ
# ID: SN65930, Navn: BOGØYA
# ID: SN37570, Navn: BORSÆ
# ID: SN90360, Navn: E8 SANDVIKEIDET
# ID: SN32061, Navn: GVARV - NES BIOFORSK
# ID: SN55702, Navn: FV424 HAUKÅSEN
# ID: SN4455, Navn: RV4 ÅNEBY
# ID: SN65275, Navn: E39 HEMNEKJØLEN
# ID: SN27010, Navn: KONNERUD
# ID: SN57990, Navn: GJENGEDAL
# ID: SN76929, Navn: YME
# ID: SN59210, Navn: RV 15 MÅLØYBRUA
# ID: SN50310, Navn: KVAMSKOGEN - JONSHØGDI
# ID: SN76938, Navn: ULA
# ID: SN91670, Navn: ULØYA - HOLTEN
# ID: SN16845, Navn: E136 LORA
# ID: SN51530, Navn: VOSSAVANGEN
# ID: SN85040, Navn: ROTVÆR
# ID: SN12700, Navn: LILLEHAMMER - VÅRSÆTERGRENDA
# ID: SN26750, Navn: FV35 HEMSDALEN HOF
# ID: SN58860, Navn: TROLLEDALSEGGA
# ID: SN50830, Navn: E16 INDRE ARNA
# ID: SN50175, Navn: AUSTEVOLL
# ID: SN79253, Navn: E12 UMBUKTA
# ID: SN3190, Navn: SARPSBORG
# ID: SN43895, Navn: FV44 KVASSHEIM
# ID: SN50525, Navn: RV555 SOTRABRUA
# ID: SN65320, Navn: FV6200 VERJESKIFTBRUA
# ID: SN25090, Navn: HEMSEDAL - FETJO
# ID: SN45770, Navn: HJELMELAND
# ID: SN56895, Navn: FV613 GAULARFJELL - MJELL
# ID: SN18810, Navn: OSLO - BYGDØY II
# ID: SN59820, Navn: FV654 HERØYBRUA
# ID: SN300400, Navn: MARINER A
# ID: SN5370, Navn: FV24 RASAN
# ID: SN17150, Navn: RYGGE
# ID: SN18020, Navn: OSLO - LAMBERTSETER
# ID: SN50507, Navn: FV5368 BØNESSKOGEN
# ID: SN58950, Navn: GRODÅS
# ID: SN4715, Navn: JESSHEIM
# ID: SN68173, Navn: TRONDHEIM - GLØSHAUGEN
# ID: SN73466, Navn: NORDLI - SANDVIKA
# ID: SN67150, Navn: LEINSTRAND
# ID: SN84905, Navn: E10 BJØRNFJELL
# ID: SN55720, Navn: SKARDSBØFJELLET
# ID: SN46820, Navn: FV520 ILSTAD
# ID: SN26992, Navn: SANDE - FOSS
# ID: SN19958, Navn: SYLLING
# ID: SN76750, Navn: SANDNESSJØEN LH - STOKKA
# ID: SN90800, Navn: TORSVÅG FYR
# ID: SN52535, Navn: FEDJE
# ID: SN86520, Navn: SORTLAND - KLEIVA
# ID: SN46380, Navn: KVANNDALEN
# ID: SN40405, Navn: RV9 BYKLE
# ID: SN39750, Navn: BYGLANDSFJORD - NESET
# ID: SN76956, Navn: GOLIAT FPSO
# ID: SN63705, Navn: OPPDAL - SÆTER
# ID: SN20954, Navn: DRAUPNER
# ID: SN52750, Navn: FRØYSET
# ID: SN77037, Navn: MS NORDBJØRN
# ID: SN27315, Navn: RAMNES - KILE VESTRE
# ID: SN496228003, Navn: HAMANG-BÆRUM-3
# ID: SN19940, Navn: LIER
# ID: SN77046, Navn: MS BILLEFJORD
# ID: SN69420, Navn: KLUKSDAL
# ID: SN33990, Navn: E134 HAUKELIFJELL
# ID: SN30249, Navn: LANGANGEN
# ID: SN1135, Navn: FV884 PRESTEBAKKE
# ID: SN62700, Navn: HUSTADVATN
# ID: SN90755, Navn: VANNVÅG II
# ID: SN90100, Navn: MALANGEN - PÅLFINNMOEN
# ID: SN27055, Navn: E18 HANEKLEIVA
# ID: SN90450, Navn: TROMSØ
# ID: SN35210, Navn: GJERSTAD JERNBANESTASJON
# ID: SN61408, Navn: E136 HORGHEIM
# ID: SN88440, Navn: SIFJORD
# ID: SN43007, Navn: E39 DRANGSDALEN
# ID: SN68110, Navn: SKISTUA
# ID: SN27073, Navn: HOLMESTRAND - BRINGÅKER
# ID: SN31550, Navn: MØSVASSDAMMEN
# ID: SN91715, Navn: FV866 SKATTØRSUND
# ID: SN27270, Navn: TØNSBERG - KILEN
# ID: SN46425, Navn: E134 RØLDALSTUNNELEN AUST
# ID: SN77405, Navn: E6 HANSMYRAN
# ID: SN44550, Navn: SOLA RADIOSONDESTASJON
# ID: SN77001, Navn: G.O. SARS
# ID: SN85560, Navn: LEKNES LUFTHAVN
# ID: SN65230, Navn: HEMNE - LENES
# ID: SN47262, Navn: KARMØY - STORASUND
# ID: SN20957, Navn: SG644 GLIDER
# ID: SN55705, Navn: RV5 KAUPANGER
# ID: SN48330, Navn: SLÅTTERØY FYR
# ID: SN46930, Navn: VATS I VINDAFJORD
# ID: SN40300, Navn: RV9 REIMAMOEN
# ID: SN69010, Navn: SVARTTJØRNBEKKEN
# ID: SN91251, Navn: MANNDALEN - VADDJA
# ID: SN27318, Navn: UNDRUMSDAL
# ID: SN60980, Navn: FV5957 GISKEBRUA
# ID: SN5660, Navn: ROVERUD
# ID: SN18310, Navn: OSLO - TØYEN
# ID: SN49631, Navn: EIDFJORD III
# ID: SN47890, Navn: OPSTVEIT
# ID: SN61070, Navn: E39 ØRSKOGFJELL
# ID: SN20930, Navn: POLARSTERN
# ID: SN90650, Navn: GRUNNFJORD - STAKKEN
# ID: SN46410, Navn: RV13 BOTNEN
# ID: SN62290, Navn: MOLDE - NØISOMHED
# ID: SN82970, Navn: E6 KRÅKMOFJELLET
# ID: SN38730, Navn: HYNNEKLEIV
# ID: SN8800, Navn: RV3 ØSTLUND
# ID: SN56010, Navn: HØYANGER VERK
# ID: SN770, Navn: ELLEFSPLASS
# ID: SN19925, Navn: LIERSKOGEN - HEIA
# ID: SN12550, Navn: KISE PÅ HEDMARK
# ID: SN90740, Navn: GRØTNESDALEN
# ID: SN71280, Navn: LEKSVIK - MYRAN
# ID: SN25640, Navn: GEILO
# ID: SN18265, Navn: E6 DJUPDALEN
# ID: SN37070, Navn: RV41 ÅMLI
# ID: SN76968, Navn: VISUNDFELTET
# ID: SN76250, Navn: SØMNA - STEIN
# ID: SN85545, Navn: LEKNES NORD
# ID: SN8450, Navn: ATNDALEN - RØNNINGEN
# ID: SN26950, Navn: SVELVIK - KNEM
# ID: SN30530, Navn: NOTODDEN
# ID: SN67153, Navn: E39 ØYSAND
# ID: SN70930, Navn: SNÅSA - NAGELHUS
# ID: SN64300, Navn: KRISTIANSUND - KARIHOLA
# ID: SN62900, Navn: EIDE PÅ NORDMØRE
# ID: SN68050, Navn: LADE
# ID: SN76950, Navn: WEST VENTURE
# ID: SN66175, Navn: FV65 BYE
# ID: SN1380, Navn: RV22 GAUTESTAD
# ID: SN49245, Navn: SKARE
# ID: SN52170, Navn: EKSINGEDAL
# ID: SN80700, Navn: GLOMFJORD
# ID: SN13160, Navn: KVITFJELL
# ID: SN76959, Navn: BRAGE
# ID: SN50770, Navn: KV4339 BLINDHEIM
# ID: SN92875, Navn: ØKSFJORD FERJEKAI
# ID: SN77040, Navn: AASTA HANSTEEN
# ID: SN79220, Navn: SKAMDAL
# ID: SN93611, Navn: RASSEGALVARRI
# ID: SN4090, Navn: VALLERUDÅSEN
# ID: SN36200, Navn: TORUNGEN FYR
# ID: SN31400, Navn: FYRIEGG
# ID: SN3731, Navn: E18 SMAALENENE VIND
# ID: SN84630, Navn: NARVIK - FAGERNESFJELLET
# ID: SN17090, Navn: E6 KARLSHUS
# ID: SN58100, Navn: SANDANE LUFTHAMN
# ID: SN86810, Navn: FV7656 BØ
# ID: SN76914, Navn: ITASMOBAWS1
# ID: SN52475, Navn: BLOMVÅG - SELE
# ID: SN76923, Navn: GULLFAKS C
# ID: SN4960, Navn: E16 UVESUND BRU
# ID: SN15430, Navn: BØVERDAL
# ID: SN36110, Navn: ARENDAL BRANNSTASJON II
# ID: SN31660, Navn: MOGEN
# ID: SN50815, Navn: E39 VÅGSBOTN
# ID: SN26932, Navn: DRAMMEN - AUSTAD
# ID: SN27282, Navn: TØNSBERG - VEAR
# ID: SN53130, Navn: FRESVIK
# ID: SN98976, Navn: TORVHAUGDALEN
# ID: SN38380, Navn: DOVLAND
# ID: SN23720, Navn: VANG I VALDRES
# ID: SN18920, Navn: OSLO - BESSERUD
# ID: SN12290, Navn: HAMAR II
# ID: SN4260, Navn: SKEDSMO - HELLERUD
# ID: SN61025, Navn: FV659 LEPSØYBRUA
# ID: SN51470, Navn: BULKEN
# ID: SN82450, Navn: TENNHOLMEN
# ID: SN16040, Navn: OTTA - SKANSEN
# ID: SN94230, Navn: ROGNSUNDET
# ID: SN12030, Navn: E6 ESPA
# ID: SN78170, Navn: E6 OSEN
# ID: SN66740, Navn: E6 ULSBERG
# ID: SN61420, Navn: MARSTEIN
# ID: SN51210, Navn: E16 DALSEID
# ID: SN43530, Navn: E39 SAGLANDSBAKKEN
# ID: SN17000, Navn: STRØMTANGEN FYR
# ID: SN2980, Navn: FV118 SVINESUND
# ID: SN35090, Navn: EIKELAND
# ID: SN91200, Navn: NORD-LENANGEN II
# ID: SN45740, Navn: NILSEBUVATNET
# ID: SN17380, Navn: RYGGE - HUGGENES
# ID: SN26594, Navn: DRAMMEN - DANVIK
# ID: SN58390, Navn: INNVIK - HEGGDAL
# ID: SN26630, Navn: VESTFOSSEN
# ID: SN90940, Navn: LANGÅSVIKA
# ID: SN50710, Navn: E39 EIDSVÅG
# ID: SN44080, Navn: OBRESTAD FYR
# ID: SN64760, Navn: SURNADAL - SYLTE
# ID: SN98790, Navn: VADSØ LUFTHAVN
# ID: SN12320, Navn: HAMAR - STAVSBERG
# ID: SN45300, Navn: LITLA TJODANVATNET
# ID: SN53680, Navn: FLÅM - JOASETBERGI
# ID: SN497459330, Navn: ULVEN-FÅBERG-330
# ID: SN18690, Navn: E18 HJORTNES
# ID: SN24710, Navn: GULSVIK II
# ID: SN91505, Navn: E6 NORDNES
# ID: SN94430, Navn: FV889 SELVIKHØYDEN
# ID: SN17030, Navn: ONSØY - EVJA
# ID: SN60247, Navn: FV60 KJELLSTADLIA
# ID: SN46610, Navn: SAUDA
# ID: SN12580, Navn: E6 RUDSHØGDA
# ID: SN31080, Navn: TESSUNGDALEN - BAKKHUS
# ID: SN87970, Navn: E6 ØSE
# ID: SN81340, Navn: FV812 HOGNDALEN
# ID: SN61010, Navn: FV659 REMMEFJELL
# ID: SN25580, Navn: RV7 KVISLA
# ID: SN68053, Navn: FV6668 HAAKON VII GATE
# ID: SN76926, Navn: SLEIPNER A
# ID: SN18645, Navn: OSLO - SOLLI PLASS
# ID: SN26872, Navn: DRAMMEN - ØREN SKOLE
# ID: SN65370, Navn: SMØLA - MOLDSTAD
# ID: SN53070, Navn: VIK I SOGN III
# ID: SN90680, Navn: DÅVØYA - KARANESSUNDET
# ID: SN80102, Navn: SOLVÆR III
# ID: SN47220, Navn: FV547 FERKINGSTAD
# ID: SN18205, Navn: OSLO - LØREN
# ID: SN4200, Navn: KJELLER
# ID: SN69865, Navn: LEVANGER II
# ID: SN60310, Navn: FV63 KORSMYRA
# ID: SN42160, Navn: LISTA FYR
# ID: SN34130, Navn: JOMFRULAND
# ID: SN27500, Navn: FÆRDER FYR
# ID: SN76917, Navn: EKOFISK - METBØYE A
# ID: SN68860, Navn: TRONDHEIM - VOLL
# ID: SN19820, Navn: HURUM RADAR
# ID: SN80730, Navn: FV17 TORSVIKA
# ID: SN60400, Navn: NORDDAL
# ID: SN90635, Navn: HESSFJORDEN - FUTNES
# ID: SN89980, Navn: TAMOKDALEN
# ID: SN61620, Navn: E136 BJORLI
# ID: SN27590, Navn: SANDEFJORD - SENTRUM
# ID: SN27285, Navn: E18 TVEITEN
# ID: SN77850, Navn: SUSENDAL
# ID: SN100, Navn: PLASSEN
# ID: SN60947, Navn: E136 ÅLESUND
# ID: SN49490, Navn: ULLENSVANG FORSØKSGARD
# ID: SN77285, Navn: GRANE NIBIO
# ID: SN85440, Navn: KVITFOSSEN I VÅGAN
# ID: SN61880, Navn: FV62 TJELLEKLEIVA
# ID: SN58480, Navn: OLDEDALEN
# ID: SN50450, Navn: FANA - STEND
# ID: SN41550, Navn: LJOSLAND - MONEN
# ID: SN82560, Navn: KJERRINGØY - STRANDÅ
# ID: SN62230, Navn: E39 HJELLSET
# ID: SN76962, Navn: HULDRAFELTET
# ID: SN36490, Navn: BØYLEFOSS
# ID: SN405, Navn: HEGGERISET - KVEEN
# ID: SN50540, Navn: BERGEN - FLORIDA
# ID: SN91245, Navn: LYNGSEIDET V
# ID: SN52415, Navn: FV57 SKODVIN
# ID: SN77240, Navn: MOSJØEN - SMALMOÅSEN
# ID: SN30380, Navn: GODAL
# ID: SN18950, Navn: TRYVANNSHØGDA
# ID: SN76935, Navn: SNORRE A
# ID: SN20520, Navn: LUNNER
# ID: SN65451, Navn: HITRA - SANDSTAD II
# ID: SN57789, Navn: FV614 GRYTADALEN
# ID: SN44780, Navn: FV4496 TENGESDAL
# ID: SN43380, Navn: EGERSUND II
# ID: SN92860, Navn: ØKSFJORD - DEALLJA
# ID: SN83960, Navn: E6 SKJELLESVIKSKARET
# ID: SN25320, Navn: ÅL III
# ID: SN17640, Navn: FV155 RÅKEN
# ID: SN77150, Navn: MIDDAGSEIDKLUMPEN
# ID: SN47600, Navn: LITLEDAL
# ID: SN55728, Navn: RV5 GUNVORDALEN
# ID: SN56850, Navn: VIKSDALEN I GAULAR
# ID: SN30320, Navn: SKIEN - ELSTRØM
# ID: SN52400, Navn: EIKANGER - MYR
# ID: SN13390, Navn: E6 FRYA
# ID: SN3019, Navn: FREDRIKSTAD BRANNSTASJON
# ID: SN88628, Navn: FV862 SENJAHOPEN
# ID: SN52570, Navn: VIKINGNESET
# ID: SN48120, Navn: STORD LUFTHAVN
# ID: SN66620, Navn: RENNEBU - RAMSTAD
# ID: SN58770, Navn: E39 LOTETUNNELEN
# ID: SN19760, Navn: ASKER - VARDÅSEN
# ID: SN78050, Navn: E6 MJÅVATN
# ID: SN30410, Navn: SKIEN - KOLLMYR
# ID: SN19428, Navn: BÆRUM - HØVIK
# ID: SN40, Navn: FV21 KROKSTAD
# ID: SN28750, Navn: FLESBERG
# ID: SN30275, Navn: SKIEN - STALSBERG
# ID: SN79764, Navn: HJARTÅSEN
# ID: SN16620, Navn: E6 AVSJØEN
# ID: SN69150, Navn: KVITHAMAR
# ID: SN64700, Navn: INNERDALEN
# ID: SN15660, Navn: SKJÅK
# ID: SN85380, Navn: SKROVA FYR
# ID: SN9380, Navn: SNØHEIM
# ID: SN68863, Navn: TRONDHEIM - VOLL PLU
# ID: SN53010, Navn: RV13 VIKAFJELL
# ID: SN85470, Navn: KONGSMARKA
# ID: SN50480, Navn: BERGEN - SANDSLI
# ID: SN91490, Navn: E8 BOSSOVARRI
# ID: SN49080, Navn: ØVRE KROSSDALEN
# ID: SN16611, Navn: E6 FOKSTUGU
# ID: SN18235, Navn: OSLO - FURUSET
# ID: SN1960, Navn: E18 ØRJE VEST
# ID: SN39570, Navn: FV42 UNDELAND
# ID: SN58070, Navn: SANDANE
# ID: SN99080, Navn: TVEIANESET
# ID: SN51440, Navn: EVANGER
# ID: SN50040, Navn: FV79 ÅLVIK AUST
# ID: SN84770, Navn: E6 HÅLOGALANDSBRUA
# ID: SN57810, Navn: SVELGEN II
# ID: SN65310, Navn: VEIHOLMEN
# ID: SN94020, Navn: ALTA - BJØRNFJELLET
# ID: SN87740, Navn: RV83 BLOMJOTEN
# ID: SN52310, Navn: MODALEN III
# ID: SN47232, Navn: ÅKREHAMN AMFI
# ID: SN40880, Navn: HOVDEN - LUNDANE
# ID: SN4140, Navn: LILLESTRØM - RÅDHUSET
# ID: SN19527, Navn: SKRIVERBERGET
# ID: SN53530, Navn: MIDTSTOVA
# ID: SN68262, Navn: KLÆBU II
# ID: SN79791, Navn: E6 SALTFJELLET
# ID: SN59586, Navn: FV61 HAREIDSDALEN
# ID: SN65920, Navn: MAUSUND
# ID: SN18280, Navn: RV4 GJELLERÅSEN
# ID: SN45590, Navn: RV13 KVAM IOT
# ID: SN59667, Navn: VOLDA - BRATTEBERG SKOLE
# ID: SN10600, Navn: AURSUND
# ID: SN51610, Navn: E16 VOSS NORD
# ID: SN80320, Navn: KILBOGHAMN
# ID: SN21680, Navn: VEST-TORPA II
# ID: SN60860, Navn: E39 SOLAVÅGEN FERJEKAI
# ID: SN30293, Navn: SKIEN - GIMSØY
# ID: SN95590, Navn: BØRSELV II
# ID: SN41795, Navn: E39 OSESTAD
# ID: SN32240, Navn: BØ
# ID: SN73250, Navn: SØRLI
# ID: SN61820, Navn: ERESFJORD
# ID: SN22990, Navn: E16 KALPLASSEN
# ID: SN34115, Navn: E18 SPRANGFOSS BRU
# ID: SN94280, Navn: HAMMERFEST LUFTHAVN
# ID: SN19455, Navn: BÆRUM - KOMMUNEGÅRDEN
# ID: SN22730, Navn: HEDAL I VALDRES II
# ID: SN30248, Navn: BREVIK
# ID: SN27162, Navn: ÅSGÅRDSTRAND
# ID: SN15050, Navn: RV15 LOM
# ID: SN5495, Navn: RV2 SIGERNESSJØEN
# ID: SN92650, Navn: NUVSVÅG
# ID: SN25110, Navn: HEMSEDAL II
# ID: SN4780, Navn: GARDERMOEN
# ID: SN68238, Navn: E6 HEIMDAL
# ID: SN60890, Navn: BRUSDALSVATN II
# ID: SN93000, Navn: HASVIK - SLUSKFJELLET
# ID: SN57660, Navn: EIMHJELLEN
# ID: SN52860, Navn: TAKLE
# ID: SN10800, Navn: SØLENDET
# ID: SN3120, Navn: ROLVSØY - ELVENESVEIEN
# ID: SN25541, Navn: BAKKO I HOL II
# ID: SN61410, Navn: MANNEN
# ID: SN81310, Navn: FV17 ÅSELIBRUA
# ID: SN19718, Navn: ASKER BRANNSTASJON II
# ID: SN41825, Navn: LYNGDAL
# ID: SN54780, Navn: ØVRE ÅRDAL
# ID: SN90560, Navn: KVALØYSLETTA
# ID: SN19790, Navn: ASKER − BØDALEN
# ID: SN48500, Navn: ROSENDAL
# ID: SN67780, Navn: ÅLEN
# ID: SN19458, Navn: NADDERUD
# ID: SN12110, Navn: STANGE - RÅDHUSET
# ID: SN47172, Navn: KARMSUND DYREHOSPITAL
# ID: SN49720, Navn: TUSSAFOTEN
# ID: SN4735, Navn: GARDERMOEN - SØRØST
# ID: SN93700, Navn: KAUTOKEINO
# ID: SN80870, Navn: FV7438 SANDHORNØYA
# ID: SN6700, Navn: RV3 SVINGEN
# ID: SN4807, Navn: ULLENSAKER − BORGEN
# ID: SN94050, Navn: ØVRE LEIRBOTN
# ID: SN39160, Navn: KRISTIANSAND - HOLDALSNUTEN
# ID: SN27730, Navn: E18 FOKSERØD
# ID: SN88640, Navn: HUSØY
# ID: SN52555, Navn: FV57 MONGSTAD SØR
# ID: SN12666, Navn: E6 VINGNES
# ID: SN48069, Navn: FV542 BØMLABRUA
# ID: SN27057, Navn: SANDE - KVERNTANGEN
# ID: SN28923, Navn: FV40 VEGGLI
# ID: SN13420, Navn: VENABU
# ID: SN27470, Navn: TORP
# ID: SN57050, Navn: ASKVOLL FERJEKAI
# ID: SN75550, Navn: SKLINNA FYR
# ID: SN68175, Navn: E6 MOHOLTLIA
# ID: SN62200, Navn: E39 FURSETFJELLET
# ID: SN60800, Navn: ØRSKOG
# ID: SN82225, Navn: BODØ - STOKKVIKA
# ID: SN90721, Navn: REBBENESØY - GRÅHAUGEN
# ID: SN4385, Navn: E6 KLØFTA
# ID: SN63420, Navn: SUNNDALSØRA III
# ID: SN90730, Navn: GRØTSUNDET - SOLHEIM
# ID: SN43090, Navn: JØSSINGFJORD
# ID: SN16560, Navn: DOMBÅS - NORDIGARD
# ID: SN7660, Navn: ÅKRESTRØMMEN
# ID: SN19530, Navn: AUREVANN
# ID: SN55740, Navn: ANESTØLEN
# ID: SN52510, Navn: FEDJEOSEN SØRVEST
# ID: SN725, Navn: FV221 VALLDALSFJELL
# ID: SN8880, Navn: ALVDAL
# ID: SN94238, Navn: KIRKEGÅRDSØYA
# ID: SN30305, Navn: FV32 KIKUT
# ID: SN6440, Navn: VERMUNDSJØEN
# ID: SN91690, Navn: KÅGEN - SKARVESTEINEN
# ID: SN47450, Navn: STRAUMØY
# ID: SN27120, Navn: HORTEN - NYKIRKE
# ID: SN50070, Navn: KVAMSØY
# ID: SN20956, Navn: SBADCP SAILBOUY 1
# ID: SN17870, Navn: ÅS - RUSTADSKOGEN
# ID: SN43350, Navn: EIGERØYA
# ID: SN99460, Navn: PASVIK - SVANVIK
# ID: SN91430, Navn: RIHPOJAVRI
# ID: SN77048, Navn: MS T.A. SENIOR
# ID: SN91780, Navn: ØVRE KILDAL
# ID: SN63725, Navn: E6 OPPDAL
# ID: SN24240, Navn: RV7 RALLERUD
# ID: SN9580, Navn: TYNSET - HANSMOEN
# ID: SN56790, Navn: E39 SANDE BRU
# ID: SN60190, Navn: ROALDSHORNET
# ID: SN44660, Navn: STAVANGER - HUNDVÅG
# ID: SN7920, Navn: FINSTAD - NYHUS
# ID: SN99370, Navn: KIRKENES LUFTHAVN
# ID: SN27075, Navn: E18 GRELLAND
# ID: SN84710, Navn: NARVIK - STASJONSVN.
# ID: SN30350, Navn: SKIEN - JØNNEVALL
# ID: SN91726, Navn: ARNØYA - LANGFJORDEN
# ID: SN80610, Navn: MYKEN
# ID: SN99110, Navn: LAUSKLUBBEN
# ID: SN44552, Navn: TANANGER
# ID: SN91080, Navn: YTRE HOLMEBUKT
# ID: SN72580, Navn: NAMSOS LUFTHAVN
# ID: SN84701, Navn: NARVIK SENTRUM
# ID: SN17251, Navn: MOSS BRANNSTASJON
# ID: SN496228005, Navn: HAMANG-BÆRUM-5
# ID: SN30242, Navn: FV301 BERG KIRKE
# ID: SN77425, Navn: MAJAVATN V
# ID: SN91502, Navn: NORDNESFJELLET - JETTANII
# ID: SN51990, Navn: MYRKDALEN-VETLEBOTN
# ID: SN88200, Navn: SENJA - LAUKHELLA
# ID: SN15905, Navn: RV15 GROTLI
# ID: SN8970, Navn: EINUNNA KRAFTVERK
# ID: SN17780, Navn: BLEKSLITJERN
# ID: SN4825, Navn: FV170 KOMPVEIEN
# ID: SN56960, Navn: HAUKEDAL
# ID: SN45530, Navn: LIARVATN
# ID: SN30000, Navn: LARVIK
# ID: SN11500, Navn: ØSTRE TOTEN - APELSVOLL
# ID: SN42650, Navn: FLEKKEFJORD
# ID: SN73630, Navn: E6 FJERDINGEN
# ID: SN80000, Navn: FV810 BUSTNESLIA
# ID: SN30278, Navn: SKIEN - KLYVE
# ID: SN496228008, Navn: HAMANG-BÆRUM-8
# ID: SN69730, Navn: SKOGN
# ID: SN11440, Navn: FV33 FEIRING
# ID: SN64320, Navn: KRISTIANSUND ELVERK
# ID: SN48072, Navn: FV542 BØMLABRUA AUST
# ID: SN98978, Navn: REINHAUGEN
# ID: SN38140, Navn: LANDVIK
# ID: SN50351, Navn: SAMNANGER II
# ID: SN58165, Navn: E39 KLAKEGG
# ID: SN17810, Navn: NESODDEN - TANGENÅSEN
# ID: SN15262, Navn: JUVFLYE - MIMISBRUNNR KLIMAPARK
# ID: SN50360, Navn: FV49 GULLBOTN
# ID: SN26450, Navn: FV287 HAGLEBU
# ID: SN17550, Navn: E6 SONSVEIEN
# ID: SN86310, Navn: GIMSØY - OSAN
# ID: SN69380, Navn: MERÅKER - VARDETUN
# ID: SN50539, Navn: BERGEN - FLORIDA UIB
# ID: SN39450, Navn: RV9 DALEHEFTE
# ID: SN60875, Navn: BRUSDALEN
# ID: SN15890, Navn: GROTLI III
# ID: SN3060, Navn: RV110 SKÅRA
# ID: SN4460, Navn: HAKADAL JERNBANESTASJON
# ID: SN25140, Navn: RV52 STORESKAR
# ID: SN66150, Navn: ORKDAL - THAMSHAMN
# ID: SN78370, Navn: BJERKA - VALLA
# ID: SN61090, Navn: TRESFJORDEN
# ID: SN91020, Navn: BREIVIKEIDET
# ID: SN93200, Navn: KVENVIKMOEN
# ID: SN92895, Navn: E6 LANGFJORDBOTN
# ID: SN31250, Navn: STRENGEN
# ID: SN20932, Navn: VESTFJORDEN
# ID: SN58560, Navn: STRYN
# ID: SN11790, Navn: FV33 VARDALSÅSEN
# ID: SN18420, Navn: OSLO - DISEN
# ID: SN39100, Navn: OKSØY FYR
# ID: SN90760, Navn: FAKKEN
# ID: SN4110, Navn: LØRENSKOG - HANEBORG
# ID: SN55770, Navn: NJØS
# ID: SN76450, Navn: VEGA - VALLSJØ
# ID: SN68420, Navn: AUNET
# ID: SN30810, Navn: TINNOSDAMMEN
# ID: SN80200, Navn: LURØY
# ID: SN58533, Navn: LOEN - RAKE
# ID: SN33430, Navn: E134 GRØNLIHEIA
# ID: SN54110, Navn: LÆRDAL IV
# ID: SN81420, Navn: FV813 BEIARFJELLET
# ID: SN19461, Navn: BRUNKOLLEN
# ID: SN87315, Navn: RV85 LANGVASSBUKT
# ID: SN66760, Navn: OPPDAL - MAURHAUGEN
# ID: SN75140, Navn: HOFLES
# ID: SN46430, Navn: RØLDALSFJELLET
# ID: SN77006, Navn: JOHAN HJORT
# ID: SN39800, Navn: RV9 LONGERAK
# ID: SN19470, Navn: MUREN
# ID: SN47498, Navn: ETNE II
# ID: SN98090, Navn: BERLEVÅG LUFTHAVN
# ID: SN55725, Navn: RV5 TYLDEN
# ID: SN66850, Navn: KVIKNE I ØSTERDAL
# ID: SN52540, Navn: FEDJE KV
# ID: SN90491, Navn: TROMSØ LH - STORKJØLEN
# ID: SN5680, Navn: RV2 FØTTASKJÆRET
# ID: SN61790, Navn: FV64 ISFJORDEN
# ID: SN93900, Navn: SIHCCAJAVRI
# ID: SN76961, Navn: SLEIPNER B
# ID: SN58910, Navn: RV15 MARKANE
# ID: SN47480, Navn: E134 VATS
# ID: SN12050, Navn: E6 VIKSELV
# ID: SN82210, Navn: RV80 BERTNES
# ID: SN77042, Navn: MS COLOR FANTASY
# ID: SN33950, Navn: HAUKELISETER TESTFELT
# ID: SN91460, Navn: E8 GARDEBORRI
# ID: SN27320, Navn: E18 UNDRUMSDAL
# ID: SN19945, Navn: LIER - SJÅSTAD
# ID: SN77051, Navn: MS POLARGIRL
# ID: SN27015, Navn: DRAMMEN - JARLSBERGVEIEN
# ID: SN42940, Navn: SIRDAL - SINNES
# ID: SN5330, Navn: FV24 STORSJØEN
# ID: SN91675, Navn: E6 DJUPVIK
# ID: SN7950, Navn: RENA FLYPLASS
# ID: SN1230, Navn: HALDEN
# ID: SN69640, Navn: E6 RONGLAN
# ID: SN57340, Navn: JØLSTER - KVAMSFJELLET
# ID: SN90670, Navn: DÅFJORD
# ID: SN91729, Navn: ARNØYA - TROLLTINDEN
# ID: SN9870, Navn: BLANKTJERNMOEN I KVIKNE
# ID: SN26970, Navn: FV319 SAGBUKTA
# ID: SN85640, Navn: E10 KÅKERN BRU
# ID: SN76937, Navn: TROLL C
# ID: SN77350, Navn: FV76 TOSENFJELLET
# ID: SN69661, Navn: E39 KVIVSVEIEN
# ID: SN76946, Navn: ROSS RIG
# ID: SN32060, Navn: GVARV - NES
# ID: SN62295, Navn: MOLDE - HINDALSRØRA
# ID: SN34680, Navn: FV38 BOSTRAK
# ID: SN50865, Navn: GULLFJELLET
# ID: SN43490, Navn: E39 UALAND
# ID: SN19930, Navn: GLITRE
# ID: SN84070, Navn: BJØRKÅSEN
# ID: SN88690, Navn: HEKKINGEN FYR
# ID: SN64242, Navn: RV70 FREI
# ID: SN49860, Navn: RV7 DYRANUT
# ID: SN52471, Navn: HJELTEFJORDEN B
# ID: SN99340, Navn: ØVRE NEIDEN
# ID: SN82410, Navn: HELLIGVÆR II
# ID: SN6840, Navn: RV3 RENA
# ID: SN76928, Navn: HEIDRUN
# ID: SN83280, Navn: FV835 ENGELØYBRUA
# ID: SN70980, Navn: E6 KVAM
# ID: SN62950, Navn: E39 GJEMNESSUNDBRUA
# ID: SN210, Navn: TRYSIL - NORDRE KANKEN
# ID: SN65130, Navn: TUSTNA
# ID: SN88430, Navn: FV7862 KAPERSKARET
# ID: SN56320, Navn: LAVIK
# ID: SN66530, Navn: MELDAL - MUAN
# ID: SN77000, Navn: POLARBJØRN
# ID: SN90305, Navn: E8 LAVANGSDALEN
# ID: SN44190, Navn: TIME - LYE
# ID: SN6580, Navn: RV2 SORMA
# ID: SN33890, Navn: VÅGSLI
# ID: SN64870, Navn: TÅGDALEN
# ID: SN41005, Navn: FV439 SUVATNET
# ID: SN120, Navn: FV2168 FLERMOBERGET
# ID: SN22200, Navn: E16 HALLINGBY
# ID: SN98640, Navn: FINNESVATNET
# ID: SN98550, Navn: VARDØ RADIO
# ID: SN24820, Navn: RV7 NESBYEN
# ID: SN93140, Navn: ALTA LUFTHAVN
# ID: SN10070, Navn: FV30 OSMOEN
# ID: SN94235, Navn: RV94 SKJÅHOLMEN
# ID: SN20540, Navn: GRAN
# ID: SN76964, Navn: NJORD A
# ID: SN2830, Navn: FV115 HEMNES
# ID: SN44567, Navn: E39 FINNESTAD
# ID: SN18405, Navn: OSLO - SANDAKER
# ID: SN15480, Navn: SKJÅK II
# ID: SN86600, Navn: STOKMARKNES LH - SKAGEN
# ID: SN17005, Navn: ONSØY - ØYENKILEN
# ID: SN46460, Navn: RØLDAL KRAFTVERK
# ID: SN67140, Navn: SKJETLEIN
# ID: SN59110, Navn: KRÅKENES
# ID: SN52390, Navn: E39 OSTEREIDET
# ID: SN20280, Navn: HØNEFOSS - HVERVEN
# ID: SN99600, Navn: FARKOLLEN
# ID: SN12600, Navn: VEA
# ID: SN44800, Navn: SVILAND
# ID: SN17400, Navn: FV120 RØDSUND
# ID: SN26650, Navn: DARBU
# ID: SN18970, Navn: OSLO - LYSAKER
# ID: SN71850, Navn: HALTEN FYR
# ID: SN53700, Navn: AURLAND
# ID: SN18701, Navn: OSLO - BLINDERN PLU
# ID: SN72200, Navn: FV17 RØDHAMMER
# ID: SN50506, Navn: E39 FJØSANGERVEIEN
# ID: SN38735, Navn: RV41 HYNNEKLEIV
# ID: SN98595, Navn: E75 DOMEN
# ID: SN18450, Navn: MARIDALSOSET
# ID: SN17050, Navn: RÅDE - TOMB
# ID: SN57630, Navn: RV5 SVARTHUMLE
# ID: SN19670, Navn: ASKER - NESBRU
# ID: SN71805, Navn: FV715 MOMYR
# ID: SN23420, Navn: FAGERNES
# ID: SN4920, Navn: ÅRNES
# ID: SN75080, Navn: FV17 NORDLANDSKORSEN
# ID: SN94800, Navn: REPVÅG
# ID: SN55970, Navn: FV55 KONGSNES
# ID: SN39040, Navn: KJEVIK
# ID: SN2480, Navn: FV21 TANGEN
# ID: SN20953, Navn: VALEMON
# ID: SN87120, Navn: ANDØYA - TROLLTINDEN
# ID: SN98580, Navn: VARDØ LUFTHAVN
# ID: SN47225, Navn: KARMØY - HEMNES
# ID: SN60, Navn: LINNES
# ID: SN78250, Navn: LEIRFJORD
# ID: SN73800, Navn: TUNNSJØ
# ID: SN81650, Navn: SALTDAL - NORDNES
# ID: SN12648, Navn: LILLEHAMMER - RÅDHUSET
# ID: SN75020, Navn: OTTERØY
# ID: SN66120, Navn: FV714 VÅVATNET
# ID: SN9050, Navn: GRIMSE
# ID: SN85840, Navn: VÆRØY HELIPORT
# ID: SN67340, Navn: E6 BUVATNET
# ID: SN32350, Navn: ÅMOTSDAL
# ID: SN4950, Navn: FV175 FOLMO
# ID: SN37150, Navn: STORGAMA
# ID: SN61060, Navn: REKDAL
# ID: SN37500, Navn: FOLDSÆ
# ID: SN26500, Navn: GEITHUS
# ID: SN47055, Navn: E39 EIKJE
# ID: SN6170, Navn: RV2 HASLEMOSLETTA
# ID: SN50150, Navn: HATLESTRAND
# ID: SN3290, Navn: RAKKESTAD
# ID: SN22840, Navn: REINLI
# ID: SN27272, Navn: TØNSBERG - EIK
# ID: SN20301, Navn: HØNEFOSS - HØYBY
# ID: SN26590, Navn: DRAMMEN - SLETTA
# ID: SN54645, Navn: E16 FILEFJELL-SMEDDALEN
# ID: SN53990, Navn: FV50 VESTREDALEN
# ID: SN74670, Navn: E6 NAMSSKOGAN
# ID: SN47270, Navn: KARMØY - HYDRO
# ID: SN95350, Navn: BANAK
# ID: SN12280, Navn: RV3 STABEKKEN
# ID: SN41860, Navn: KVINESHEI - SØRHELLE
# ID: SN51460, Navn: E16 EIDESMOEN
# ID: SN76931, Navn: TROLL A
# ID: SN76967, Navn: OSEBERG SØR
# ID: SN20929, Navn: JOHAN SVERDRUP
# ID: SN82000, Navn: SETSÅ
# ID: SN54600, Navn: MARISTOVA
# ID: SN55820, Navn: FJÆRLAND - BREMUSEET
# ID: SN96400, Navn: SLETTNES FYR
# ID: SN52940, Navn: E39 KRINGLA
# ID: SN13150, Navn: FÅVANG
# ID: SN14550, Navn: PRESTSTULEN
# ID: SN76922, Navn: STATFJORD A
# ID: SN76240, Navn: SØMNA - KVALØYFJELLET
# ID: SN63940, Navn: E6 GRØNBAKKEN
# ID: SN19825, Navn: TOFTE - RULLETO
# ID: SN69960, Navn: BURAN
# ID: SN89985, Navn: SJUFJELLET
# ID: SN69655, Navn: FROSTA
# ID: SN50500, Navn: FLESLAND
# ID: SN27281, Navn: TØNSBERG - BARKÅKER
# ID: SN97710, Navn: ISKORAS II
# ID: SN50850, Navn: FV587 HAUKELAND
# ID: SN8135, Navn: RV3 EVENSTAD
# ID: SN76330, Navn: BRØNNØYSUND LUFTHAVN
# ID: SN91528, Navn: GAMANJUNNI - 1100MOH
# ID: SN84925, Navn: E10 GROVFJORD VEGKRYSS
# ID: SN12980, Navn: LILLEHAMMER - BJØRNERUD
# ID: SN60620, Navn: GRØNNING
# ID: SN69520, Navn: E14 TEVELDALEN
# ID: SN13760, Navn: FV51 VALDRESFLYE
# ID: SN3730, Navn: E18 SMÅLENENES BRU
# ID: SN25630, Navn: GEILO - OLDEBRÅTEN
# ID: SN14200, Navn: LEIRFLATEN
# ID: SN57830, Navn: FV614 LANGESI
# ID: SN93170, Navn: ALTA - KAISKURU
# ID: SN89940, Navn: DIVIDALEN II
# ID: SN76958, Navn: ÅSGARD B
# ID: SN62980, Navn: GJEMNES - REINSFJELLET
# ID: SN90290, Navn: NORDRE ANGSTAURSUNDET
# ID: SN61580, Navn: E136 BRUSTUGLIA
# ID: SN43520, Navn: FV42 TVERRÅ
# ID: SN99540, Navn: NYRUD
# ID: SN92910, Navn: SOPNESBUKT
# ID: SN96310, Navn: MEHAMN LUFTHAVN
# ID: SN55300, Navn: SKJOLDEN
# ID: SN84880, Navn: KATTERAT
# ID: SN85535, Navn: LEKNES - FYGLE
# ID: SN57480, Navn: BOTNEN I FØRDE
# ID: SN91510, Navn: MANNDALEN II
# ID: SN9310, Navn: HJERKINN II
# ID: SN50231, Navn: EIKELANDSOSEN
# ID: SN56520, Navn: HOVLANDSDAL
# ID: SN88630, Navn: FJORDGÅRD
# ID: SN49800, Navn: FET I EIDFJORD
# ID: SN11060, Navn: FV181 FINSBRÅTAN
# ID: SN3030, Navn: FREDRIKSTAD
# ID: SN30340, Navn: SKIEN - PETERSBORG
# ID: SN3003, Navn: E6 SOLBERGTÅRNET SYD
# ID: SN37760, Navn: FYRESDAL
# ID: SN84970, Navn: EVENES LUFTHAVN
# ID: SN27460, Navn: NØTTERØY - BORGHEIM
# ID: SN9400, Navn: RV3 BERGERØNNINGEN
# ID: SN10055, Navn: TOLGA
# ID: SN55928, Navn: BALESTRAND - BALE
# ID: SN59660, Navn: VOLDA
# ID: SN3990, Navn: RV22 KROKEDAL
# ID: SN23800, Navn: YLJA KRAFTVERK
# ID: SN80340, Navn: TRÆNA - HUSØY
# ID: SN24670, Navn: FV280 ENDERUD BRU
# ID: SN60010, Navn: SYKKYLVEN - VIK
# ID: SN56780, Navn: SYGNA
# ID: SN44480, Navn: SØYLAND I GJESDAL
# ID: SN45350, Navn: LYSEBOTN
# ID: SN18390, Navn: OSLO - BJØLSEN
# ID: SN50527, Navn: KV4821 NIPEDALEN
# ID: SN99917, Navn: BAYELVA
# ID: SN47264, Navn: KARMØY - HARALDSVIK
# ID: SN90, Navn: RV25 MIDTSKOGBERGET
# ID: SN26934, Navn: DRAMMEN - SOLUMSTRAND
# ID: SN84910, Navn: E10 SKITDALSHØGDA
# ID: SN27400, Navn: NØTTERØY - FØYNLAND
# ID: SN30325, Navn: SKIEN - LANGEDUKEN
# ID: SN90490, Navn: TROMSØ - LANGNES
# ID: SN55850, Navn: RV5 BØYADALEN
# ID: SN76530, Navn: TJØTTA
# ID: SN76934, Navn: STATFJORD B
# ID: SN47820, Navn: EIKEMO
# ID: SN1400, Navn: BREKKE SLUSE
# ID: SN45685, Navn: RV13 BYRKJA
# ID: SN77490, Navn: KAPPFJELLET
# ID: SN28450, Navn: E134 MEHEIA
# ID: SN86740, Navn: BØ I VESTERÅLEN III
# ID: SN58030, Navn: FV615 HYEN
# ID: SN3015, Navn: BORGE - BERG
# ID: SN33250, Navn: RAULAND
# ID: SN92760, Navn: HASVIK HAVN
# ID: SN47300, Navn: UTSIRA FYR
# ID: SN57770, Navn: YTTERØYANE FYR
# ID: SN76925, Navn: DRAUGEN
# ID: SN50395, Navn: E39 MOBERGSBRUA
# ID: SN85080, Navn: KANSTADBOTN
# ID: SN78800, Navn: VARNTRESK
# ID: SN43810, Navn: MAUDAL
# ID: SN17280, Navn: GULLHOLMEN
# ID: SN9250, Navn: FV29 GRAVBEKKLIA
# ID: SN87000, Navn: ÅNSTADBLÅHEIA
# ID: SN49085, Navn: FOLGEFONNA SKISENTER
# ID: SN11000, Navn: FV705 LANGSVOLA
# ID: SN2970, Navn: E16 ØYERMOEN
# ID: SN70510, Navn: VERA II
# ID: SN31680, Navn: HANSBU
# ID: SN87763, Navn: E10 TJELDSUNDBRUA ØST
# ID: SN30280, Navn: FV353 BRUMYRDAL
# ID: SN52360, Navn: E39 ROMARHEIMSDALEN
# ID: SN5590, Navn: KONGSVINGER
# ID: SN53230, Navn: E16 LANGHUSO
# ID: SN4190, Navn: LILLESTRØM - BADEVEIEN
# ID: SN87117, Navn: FV82 KJØLHÅGEN
# ID: SN18240, Navn: E6 FURUSET
# ID: SN85448, Navn: SVOLVÆR LH - NORD
# ID: SN92500, Navn: LANGFJORDJØKELEN
# ID: SN24960, Navn: GOL - STAKE
# ID: SN94680, Navn: HONNINGSVÅG LUFTHAVN
# ID: SN39010, Navn: KRISTIANSAND - FIDJEÅSEN
# ID: SN47910, Navn: MIDTBOTN
# ID: SN10300, Navn: HÅSJØEN - SOLGLØTT
# ID: SN44985, Navn: FV450 HUNNEDALEN
# ID: SN45640, Navn: RV13 MÅLANDSDALEN IOT
# ID: SN75220, Navn: RØRVIK LUFTHAVN
# ID: SN46510, Navn: E134 MIDTLÆGER
# ID: SN26898, Navn: DRAMMEN - ÅSSIDEN
# ID: SN87772, Navn: SÆTERTINDEN VED TJELDSUNDET
# ID: SN27212, Navn: FON
# ID: SN4827, Navn: FV172 HOLTER
# ID: SN58703, Navn: RV15 SKJERDINGSDALEN
# ID: SN23300, Navn: FV51 GOLSFJELLET
# ID: SN7420, Navn: RENA - ØRNHAUGEN
# ID: SN84210, Navn: LOSISTUA
# ID: SN39970, Navn: E39 MONANKRYSSET
# ID: SN67280, Navn: SOKNEDAL
# ID: SN59250, Navn: REFVIK
# ID: SN89360, Navn: BARDUFOSS - RUSTAFJELLET
# ID: SN60650, Navn: LINGE
# ID: SN49220, Navn: ODDA - JORDAL
# ID: SN32290, Navn: RV36 SELJORD
# ID: SN52970, Navn: SØREBØ
# ID: SN58990, Navn: RV15 TOTLAND
# ID: SN26790, Navn: MJØNDALEN - ORKIDEHØGDA
# ID: SN17980, Navn: OSLO - LJABRUVEIEN
# ID: SN65145, Navn: AURE
# ID: SN40840, Navn: RV9 HOVDEN II
# ID: SN26862, Navn: DRAMMEN TINGHUS
# ID: SN700, Navn: DREVSJØ
# ID: SN82290, Navn: BODØ VI
# ID: SN24350, Navn: RV350 NAKKERUD
# ID: SN50503, Navn: SÆDALEN
# ID: SN18500, Navn: BJØRNHOLT
# ID: SN76790, Navn: SANDNESSJØEN - STAMNESØRA
# ID: SN18195, Navn: OSLO - HØYENHALL
# ID: SN77230, Navn: MOSJØEN LUFTHAVN
# ID: SN63880, Navn: E6 DRIVSTUA
# ID: SN89010, Navn: KISTEFJELL
# ID: SN62480, Navn: ONA II
# ID: SN74350, Navn: NAMSSKOGAN
# ID: SN69550, Navn: ØSTÅS I HEGRA
# ID: SN22690, Navn: E16 BEGNADALEN
# ID: SN88023, Navn: FV848 FORNES
# ID: SN83600, Navn: E6 ULVSVÅGSKARET
# ID: SN48170, Navn: E39 MEHAMMAR
# ID: SN96250, Navn: FV888 STORE REINOKSEVATN
# ID: SN19810, Navn: RØYKEN - SKOGSBORG
# ID: SN96600, Navn: GAMVIK - SKJÅNES
# ID: SN67890, Navn: FV30 RUGLDALEN
# ID: SN25830, Navn: FINSEVATN
# ID: SN47192, Navn: SKUDENES INDUSTRI
# ID: SN33555, Navn: E134 VINJE
# ID: SN79700, Navn: STORFORSHEI
# ID: SN25115, Navn: HEMSEDAL SKISENTER
# ID: SN4785, Navn: GARDERMOEN PLU
# ID: SN68270, Navn: LØKSMYR
# ID: SN63820, Navn: DRIVDALEN
# ID: SN92350, Navn: NORDSTRAUM I KVÆNANGEN
# ID: SN18180, Navn: OSLO - TRASOP
# ID: SN39201, Navn: KRISTIANSAND - BRÅVANN
# ID: SN31853, Navn: E134 GVAMMEN
# ID: SN27403, Navn: NØTTERØY - KNARRBERG
# ID: SN54740, Navn: FV53 NADDVIK
# ID: SN11900, Navn: BIRI
# ID: SN39210, Navn: DUEKNIPEN
# ID: SN62160, Navn: ISTAD KRAFTSTASJON
# ID: SN81315, Navn: FV17 SALTSTRAUMBRUA
# ID: SN82840, Navn: STRØKSNES - HESTVIKA
# ID: SN41175, Navn: LAUDAL - KLEIVEN
# ID: SN67005, Navn: E39 KALLFOSS
# ID: SN19490, Navn: GJETTUM PLU
# ID: SN60850, Navn: EMBLEM
# ID: SN55709, Navn: RV5 LOFTESNES
# ID: SN22890, Navn: FV33 TONSÅSEN
# ID: SN16610, Navn: FOKSTUGU
# ID: SN35110, Navn: E18 ØSTERHOLTHEIA
# ID: SN76470, Navn: HØYHOLM
# ID: SN61810, Navn: FV660 VISTDALSHEIA
# ID: SN99420, Navn: E6 KIRKENES SYD
# ID: SN41480, Navn: ÅSERAL
# ID: SN27161, Navn: HORTEN - SKOPPUM
# ID: SN91740, Navn: SØRKJOSEN LUFTHAVN
# ID: SN29350, Navn: UVDAL KRAFTVERK
# ID: SN38250, Navn: E18 STUDEVANN
# ID: SN96890, Navn: KORGÅSEN
# ID: SN50120, Navn: SKULAFOSSEN KRAFTSTASJON
# ID: SN31970, Navn: GAUSTATOPPEN
# ID: SN60500, Navn: TAFJORD
# ID: SN77403, Navn: E6 MAJAVATN
# ID: SN91480, Navn: E8 GALGO
# ID: SN50102, Navn: KVAM-VALLAND
# ID: SN44620, Navn: STAVANGER - TASTA
# ID: SN56490, Navn: VÆRLANDET
# ID: SN13030, Navn: GAUSDAL - FOLLEBU
# ID: SN730, Navn: VALDALEN
# ID: SN60240, Navn: ÅKERNESET
# ID: SN8230, Navn: RV3 KOPPANG
# ID: SN1600, Navn: FV21 AREBEKKEN
# ID: SN89820, Navn: ØVERBYGD II
# ID: SN54731, Navn: FV2515 FILEFJELL-VARDEN
# ID: SN62860, Navn: FV64 ATLANTERHAVSVEGEN
# ID: SN1950, Navn: ØRJE
# ID: SN91695, Navn: FV866 MAURSUND
# ID: SN44710, Navn: E39 FORUS
# ID: SN4543, Navn: RV4 STRYKEN
# ID: SN17875, Navn: E18 HOLSTAD
# ID: SN99160, Navn: OTERFJORDEN
# ID: SN31620, Navn: MØSSTRAND II
# ID: SN84500, Navn: STRAUMSNES
# ID: SN91130, Navn: LYNGEN - GJERDVASSBU
# ID: SN55700, Navn: SOGNDAL LUFTHAMN
# ID: SN58320, Navn: MYKLEBUST I BREIM
# ID: SN66045, Navn: FV710 KJØRMOEN
# ID: SN2650, Navn: AURSKOG II
# ID: SN99680, Navn: JARFJORDEN - BÅTHAMNA
# ID: SN58670, Navn: RV15 FOSNES
# ID: SN18162, Navn: OSLO - KVÆRNERBYEN
# ID: SN23680, Navn: E16 HUGAVIKA
# ID: SN3780, Navn: IGSI I HOBØL
# ID: SN71320, Navn: RISSA III
# ID: SN91220, Navn: LYNGEN - ÅRØYA
# ID: SN29700, Navn: FV40 DAGALIFJELL
# ID: SN36330, Navn: ARENDAL LUFTHAVN
# ID: SN91731, Navn: ÅRVIKSAND
# ID: SN18270, Navn: OSLO - VESTLI
# ID: SN77035, Navn: KRONPRINS HAAKON
# ID: SN80615, Navn: ENGABREEN - SKJÆRET
# ID: SN44970, Navn: FV45 DIRDAL
# ID: SN42700, Navn: E39 REKEVIK
# ID: SN2560, Navn: FV169 ÅSERUD
# ID: SN30247, Navn: E18 TELEMARKSPORTEN
# ID: SN4740, Navn: UKKESTAD
# ID: SN93301, Navn: SUOLOVUOPMI - LULIT
# ID: SN26820, Navn: HOKKSUND
# ID: SN30256, Navn: PORSGRUNN - HERØYA
# ID: SN80050, Navn: FV17 SJONFJELLET
# ID: SN11110, Navn: SESVOLL
# ID: SN39165, Navn: KRISTIANSAND BRANNSTASJON
# ID: SN47240, Navn: KARMØY - BREKKEVANN
# ID: SN27780, Navn: TJØLLING
# ID: SN57710, Navn: FLORØ LUFTHAMN
# ID: SN18225, Navn: OSLO - TONSENHAGEN
# ID: SN58060, Navn: E39 REED
# ID: SN30875, Navn: BUSNES
# ID: SN87640, Navn: HARSTAD STADION
# ID: SN79610, Navn: SKONSENG
# ID: SN38600, Navn: MYKLAND
# ID: SN44548, Navn: SOLA PLU
# ID: SN26802, Navn: MJØNDALEN - ÅSEN
# ID: SN51250, Navn: ØVSTEDAL
# ID: SN80705, Navn: GLOMFJORD - SKIHYTTA
# ID: SN46800, Navn: FV520 SVANDALSFOSSEN
# ID: SN56400, Navn: YTRE SOLUND
# ID: SN18440, Navn: OSLO - KJELSÅS
# ID: SN67175, Navn: E6 KVÅL
# ID: SN32490, Navn: SØVE
# ID: SN496228013, Navn: HAMANG-BÆRUM-13
# ID: SN4815, Navn: STENSBYMOEN
# ID: SN49970, Navn: DJØNNO
# ID: SN90110, Navn: MORTENHALSSKOLTEN
# ID: SN28922, Navn: VEGGLI II
# ID: SN45870, Navn: FISTER - SIGMUNDSTAD
# ID: SN31210, Navn: MÅR - SYNKEN
# ID: SN31560, Navn: FV37 RAULANDSFJELLET
# ID: SN4725, Navn: E16 GARDERMOEN
# ID: SN75190, Navn: FV770 RØRVIK
# ID: SN37580, Navn: FV450 VØYLEN
# ID: SN32780, Navn: HØIDALEN I SOLUM
# ID: SN38800, Navn: TOVDAL
# ID: SN65330, Navn: EDØY
# ID: SN60880, Navn: E39 BRUSDALEN
# ID: SN29900, Navn: SKURDEVIKÅI
# ID: SN69035, Navn: E6 MALVIK
# ID: SN39150, Navn: KRISTIANSAND - SØMSKLEIVA
# ID: SN98974, Navn: BERGEBYDALEN
# ID: SN3720, Navn: ASKIM - KYKKELSRUD
# ID: SN19663, Navn: E16 SOLLIHØGDA VEST
# ID: SN26670, Navn: HAKAVIK
# ID: SN47350, Navn: RØVÆR
# ID: SN59220, Navn: BÅTESUNDSKJERET
# ID: SN18210, Navn: OSLO - HOVIN
# ID: SN30860, Navn: BERGELIGREND
# ID: SN27433, Navn: NØTTERØY - TENVIK
# ID: SN12710, Navn: LILLEHAMMER - NORDSETERVEGEN HØYDEBASSENG
# ID: SN81775, Navn: LØNSDAL STASJON
# ID: SN54815, Navn: FV53 TYINOSEN
# ID: SN37230, Navn: TVEITSUND
# ID: SN65940, Navn: SULA
# ID: SN66810, Navn: RV3 LITJFOSSEN
# ID: SN496228022, Navn: HAMANG-BÆRUM-22
# ID: SN25100, Navn: HEMSEDAL - HØLTO
# ID: SN21700, Navn: FV250 VINGROMÅSEN
# ID: SN11463, Navn: E6 MINNESUND
# ID: SN60225, Navn: FV60 STRANDAFJELLET
# ID: SN27406, Navn: NØTTERØY - TORØD
# ID: SN55775, Navn: HERMANSVERK
# ID: SN46220, Navn: GULLINGEN SKISENTER
# ID: SN18165, Navn: OSLO - RYEN
# ID: SN66900, Navn: RV3 KVIKNESKOGEN
# ID: SN27415, Navn: FV308 TJØME-BUDAL
# ID: SN68120, Navn: SAUPSTAD
# ID: SN26060, Navn: SKOTSELV
# ID: SN54770, Navn: FV53 BRENNBORG
# ID: SN57390, Navn: SKEI I JØLSTER
# ID: SN19780, Navn: ASKER - VOLLEN
# ID: SN89213, Navn: FV84 GUMPEN
# ID: SN58960, Navn: HORNINDAL
# ID: SN27630, Navn: SANDEFJORD - ENGA
# ID: SN14711, Navn: GROV - SOLHAUG
# ID: SN670, Navn: FV26 SKARVEN
# ID: SN70390, Navn: FV72 INNSMOEN
# ID: SN60835, Navn: E39 DRAGSUNDET
# ID: SN44300, Navn: SÆRHEIM
# ID: SN6690, Navn: RV3 EBRU
# ID: SN55425, Navn: SPØRTEGGBU
# ID: SN27065, Navn: FV313 BOGEN
# ID: SN13060, Navn: GAUSDAL - OVREHAGEN
# ID: SN41770, Navn: LINDESNES FYR
# ID: SN3810, Navn: ASKIM II
# ID: SN62450, Navn: FINNØYA FERJEKAI
# ID: SN54420, Navn: ØLJUSJØ PUMPEKRAFTVERK
# ID: SN88450, Navn: SENJA - MEDBY
# ID: SN18703, Navn: OSLO - BLINDERN TESTFELT
# ID: SN75100, Navn: LIAFOSS
# ID: SN46390, Navn: HOLMEVATN
# ID: SN19430, Navn: E18 SANDVIKA
# ID: SN91725, Navn: SKJERVØY
# ID: SN36055, Navn: ARENDAL SENTRUM
# ID: SN20955, Navn: SLOKUM GLIDER 1
# ID: SN49351, Navn: TYSSEDAL IA
# ID: SN96220, Navn: LEBESBY - KARLMYHR
# ID: SN53101, Navn: VANGSNES
# ID: SN82215, Navn: BODØ - ØVRE HUNSTAD
# ID: SN55712, Navn: SOGNDAL KULTURHUS
# ID: SN91770, Navn: NORDREISA - GALSOMELEN
# ID: SN98400, Navn: MAKKAUR FYR
# ID: SN24230, Navn: FV288 SOKNA
# ID: SN49360, Navn: TYSSEDAL V
# ID: SN90720, Navn: MÅSVIK
# ID: SN51980, Navn: MYRKDALEN-ONDRAHAUGEN
# ID: SN44605, Navn: E39 RENNESØY
# ID: SN90451, Navn: TROMSØ PLU
# ID: SN55730, Navn: SOGNDAL - SELSENG
# ID: SN50311, Navn: FV49 KVAMSKOGEN
# ID: SN499999010, Navn: BLINDERN-KVT-IOT
# ID: SN98642, Navn: KOMMAGDALEN
# ID: SN58350, Navn: FV60 UTVIKFJELLET
# ID: SN71000, Navn: STEINKJER - SØNDRE EGGE
# ID: SN25540, Navn: BAKKO I HOL
# ID: SN36010, Navn: FV421 HASLESTAD
# ID: SN20946, Navn: ÅSGARD A
# ID: SN77029, Navn: WEST HERCULES
# ID: SN3200, Navn: BATERØD
# ID: SN91420, Navn: E8 HALSEBAKKAN NEDRE
# ID: SN44560, Navn: SOLA
# ID: SN26975, Navn: SVELVIK - BOKERØYA
# ID: SN27316, Navn: REVETAL
# ID: SN55715, Navn: RV5 AMLA BRU
# ID: SN90400, Navn: TROMSØ - HOLT
# ID: SN85645, Navn: E10 AKKARVIKA
# ID: SN40005, Navn: RV9 HEKNI
# ID: SN12291, Navn: E6 VIEN
# ID: SN82110, Navn: VALNESFJORD
# ID: SN76969, Navn: KVITEBJØRNFELTET
# ID: SN49910, Navn: ULVIK - HJELTNES
# ID: SN70680, Navn: MÆRE III
# ID: SN31850, Navn: HJARTDAL
# ID: SN55930, Navn: BALESTRAND BRANNSTASJON
# ID: SN63000, Navn: FV62 EIDSØRA
# ID: SN75650, Navn: SKEI FERJEKAI
# ID: SN23560, Navn: BEITO
# ID: SN27301, Navn: RAMNES - BERG
# ID: SN20949, Navn: GINA KROG
# ID: SN77032, Navn: TRANSOCEAN ENABLER
# ID: SN71550, Navn: ØRLAND III
# ID: SN82020, Navn: E6 TUSSVIKA
# ID: SN51597, Navn: RV13 SVELGANE
# ID: SN36560, Navn: NELAUG
# ID: SN97470, Navn: RV92 SUOSSJAVRI
# ID: SN49955, Navn: FV572 EDDEGJELET
# ID: SN49865, Navn: RV7 SKULEVIKA
# ID: SN11125, Navn: E6 ANDELVA
# ID: SN9384, Navn: DOVREFJELL DB1
# ID: SN71290, Navn: VANVIKAN
# ID: SN78360, Navn: SELJELIA
# ID: SN16400, Navn: DOVRE-LANNEM
# ID: SN76933, Navn: ORMEN LANGE
# ID: SN42930, Navn: SIRDAL - SMØLEHEIKNUDEN
# ID: SN34900, Navn: POSTMYR I DRANGEDAL
# ID: SN31500, Navn: FRØYSTUL
# ID: SN91010, Navn: FV91 BREIVIKEIDET
# ID: SN7940, Navn: RENA - SVESTAD
# ID: SN77005, Navn: FF HELMER HANSSEN
# ID: SN9160, Navn: FOLLDAL - FREDHEIM
# ID: SN44563, Navn: RV509 SUNDEKROSSEN
# ID: SN11340, Navn: RV4 LYGNA
# ID: SN44545, Navn: FV510 REGE
# ID: SN85582, Navn: VESTVÅGØY - GRAVDAL
# ID: SN35860, Navn: LYNGØR FYR
# ID: SN57940, Navn: ÅLFOTEN II
# ID: SN52458, Navn: FV5256 STEINRUSTEN
# ID: SN30235, Navn: LARVIK - FUGLØYA
# ID: SN98645, Navn: HUBEHYTTA
# ID: SN59815, Navn: FV5876 RUNDEBRUA
# ID: SN94500, Navn: FRUHOLMEN FYR
# ID: SN6020, Navn: FLISA II
# ID: SN76960, Navn: GRANEFELTET
# ID: SN44760, Navn: IMS
# ID: SN65530, Navn: FV714 HITRA
# ID: SN58810, Navn: RV651 STIGEDALEN
# ID: SN69280, Navn: E14 MEÅDAL
# ID: SN91728, Navn: FV7940 ARNØYA
# ID: SN57850, Navn: DAVIKNES
# ID: SN60030, Navn: SYKKYLVEN - STRAUMGJERDET
# ID: SN71900, Navn: BESSAKER
# ID: SN25040, Navn: RV52 EIKREDAMMEN
# ID: SN77041, Navn: GUDRUNFELTET
# ID: SN84900, Navn: BJØRNFJELL
# ID: SN94455, Navn: INGØY III
# ID: SN69020, Navn: RANHEIM
# ID: SN31410, Navn: RJUKAN
# ID: SN45460, Navn: FV523 JØRPELAND
# ID: SN60990, Navn: VIGRA
# ID: SN71990, Navn: BUHOLMRÅSA FYR
# ID: SN61340, Navn: ÅNDALSNES - KAMSHAUGEN
# ID: SN26996, Navn: SANDE - LAUVKOLLMYR
# ID: SN94195, Navn: E6 AISAROAIVI
# ID: SN73210, Navn: FV74 SANDØLA
# ID: SN54710, Navn: FILEFJELL - KYRKJESTØLANE
# ID: SN11690, Navn: RV4 EINA
# ID: SN58900, Navn: STRYN - KROKEN
# ID: SN44554, Navn: SOLA - GRANNES
# ID: SN81760, Navn: RV77 GRADDIS
# ID: SN84380, Navn: E6 SKJOMENBRUA
# ID: SN55670, Navn: VEITASTROND
# ID: SN35340, Navn: RISØR BRANNSTASJON
# ID: SN18410, Navn: RV4 AKER SYKEHUS
# ID: SN10380, Navn: RØROS LUFTHAVN
# ID: SN25112, Navn: HEMSEDAL - HOLLEKOLTEN
# ID: SN30244, Navn: E18 VASSBOTN
# ID: SN496228007, Navn: HAMANG-BÆRUM-7
# ID: SN13655, Navn: SKÅBU
# ID: SN82720, Navn: SISOVATNET
# ID: SN89350, Navn: BARDUFOSS
# ID: SN48071, Navn: FV542 BØMLABRUA VEST
# ID: SN47730, Navn: E134 FJÆRA
# ID: SN61062, Navn: TOMREFJORD
# ID: SN97120, Navn: E6 BARTA
# ID: SN15270, Navn: JUVVASSHØE
# ID: SN74780, Navn: NAMSVATN II
# ID: SN94805, Navn: E69 VEDBOTN
